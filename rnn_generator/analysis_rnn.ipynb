# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('training_perf.txt').set_index('batch')
df.describe()
# Out:
#              loss  batches / s
# count  100.000000   100.000000
# mean     1.240862     1.242480
# std      0.396803     5.662553
# min      1.005540     0.632589
# 25%      1.081033     0.655842
# 50%      1.132205     0.658886
# 75%      1.232112     0.666121
# max      3.868520    57.300394

# %%
df['loss'].plot()
plt.ylabel("loss")
plt.savefig("saved/RNNlossPerBatch.jpg")
plt.show()

# %%
result = pd.read_csv('results.csv')
result
# Out:
#    char_length                                   lyrics generated  batch  \
# 0          500  the true last theres when youll cry huh ha ice...   1000
# 1          500  baby its feeling all i am a ranuasair the word...   3500
# 2          500  the world in criminaas pearls are relesod you ...  10000
# 3         5000  the only thing hates somethin that makes you g...  10000
# 4          750  the week to our backseat sunlight make you cry...  10000
# 5          750  baby all by dreaming i was filled with you we ...  10000
# 6          750  christmas was never the lyrice special late pu...  10000
#
#       loss
# 0  1.41155
# 1  1.11893
# 2  1.05188
# 3  1.05188
# 4  1.05188
# 5  1.05188
# 6  1.05188

# %%
i = 0
for lyrics in result['lyrics generated']:
    print("Lyrics", i)
    process = lyrics.strip().split(' ')[:-1]
    for j in range(0, len(process), 7):
        print('\t',end='')
        print(' '.join(process[j:j+7]))
    i+=1
# Out:
# Lyrics 0
# 	the true last theres when youll cry
# 	huh ha ice feelen sexy gred girlght
# 	downly the i sew nike that heaven
# 	these niggas slee in it i had
# 	me love some pain everything we gonna
# 	your bod i got on been fallings
# 	makeeve locking for loving youthe hug re
# 	gone i am bad break such a
# 	how one money than youre alive lovers
# 	know come falliecy bring oh dod bag
# 	boy must betond and but me its
# 	are ara yeah all atayah i am
# 	adrievery got a love in your always
# 	from my breath so burne waited all
# 	come out girl that you
# Lyrics 1
# 	baby its feeling all i am a
# 	ranuasair the words seems and im readin
# 	bleck and oh just fross with you
# 	somebody you stopreys so in your sars
# 	ive spret you wont you cry im
# 	nothing you know that theyre that she
# 	want bying to youre all a borgether
# 	any two chorhest feeling sown lets gave
# 	up to get it everything in my
# 	pretty foot the skndos im shroke thats
# 	started one no rolo room com the
# ...

# %%
data = pd.read_csv('../billboard_lyrics_1964-2015.csv', encoding='latin1', error_bad_lines=False)
data
# Out:
#       Rank                                      Song  \
# 0        1                               wooly bully
# 1        2  i cant help myself sugar pie honey bunch
# 2        3                i cant get no satisfaction
# 3        4                       you were on my mind
# 4        5              youve lost that lovin feelin
# 5        6                                  downtown
# 6        7                                      help
# 7        8               cant you hear my heart beat
# 8        9                      crying in the chapel
# 9       10                                   my girl
# 10      11                            help me rhonda
# 11      12                          king of the road
# 12      13                    the birds and the bees
# 13      14                 hold me thrill me kiss me
# 14      15                                   shotgun
# 15      16                            i got you babe
# 16      17                         this diamond ring
# ...
